# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PyTorchのDatadetを使用する" data-toc-modified-id="PyTorchのDatadetを使用する-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PyTorchのDatadetを使用する</a></span><ul class="toc-item"><li><span><a href="#Datasetクラス" data-toc-modified-id="Datasetクラス-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Datasetクラス</a></span></li><li><span><a href="#Transform" data-toc-modified-id="Transform-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Transform</a></span></li><li><span><a href="#Iterationg-through-the-data" data-toc-modified-id="Iterationg-through-the-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Iterationg through the data</a></span></li></ul></li></ul></div>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
import torch
from skimage import io, transform
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torchvision

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# 機械学習ではデータの準備が煩雑となる。PyTorchでは、これらを手助けして、読みやすいコードにするための
# 便利な機能がそなわっている。
#
# #
#
# チュートリアルとして`faces`データを使用する。
# (チュートリアルページからDLL可能)
#
# 顔画像と特徴点が記載されたcsvデータが入っている。

# %%
landmarks_frame = pd.read_csv('data/faces/face_landmarks.csv')

landmarks_frame.head()
# Out:
#                   image_name  part_0_x  part_0_y  part_1_x  part_1_y  \
# 0        0805personali01.jpg        27        83        27        98
# 1  1084239450_e76e00b7e7.jpg        70       236        71       257
# 2         10comm-decarlo.jpg        66       114        65       128
# 3   110276240_bec305da91.jpg        42       140        45       161
# 4             1198_0_861.jpg       138       392       141       427
#
#    part_2_x  part_2_y  part_3_x  part_3_y  part_4_x  ...  part_63_x  \
# 0        29       113        33       127        39  ...         93
# 1        75       278        82       299        90  ...        148
# 2        67       142        68       156        72  ...        128
# 3        51       180        61       200        73  ...        144
# 4       145       464       152       501       166  ...        293
#
#    part_63_y  part_64_x  part_64_y  part_65_x  part_65_y  part_66_x  \
# 0        136        100        141         93        135         89
# ...

# %%
# nullデータがあるか確認
landmarks_frame.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# カラムの1列目に画像の名前、2列目以降には特徴点の場所がx,y座標で格納されている。
#
# 各画像で68個の特徴点が記録されている。
# (nullデータは無いようなので、すべての画像で68個の特徴点が記述されている模様)

# %% [markdown]
# **Tips**
#
# - `reshape`の次元で`-1`を指定することも可能
# - この場合、入力配列の要素数と残りのshapeの次元から、`-1`に指定した次元の要素数が自動で判別される
# - `reshape(-1)`とすると、`flatten()`と同じになる。
#     - Andrew先生の推奨としてベクトルをnumpyの配列としてではなく、一次元のmatrixとして扱う、ということがあった
#     - その場合は、`v.reshape(1, -1)`とすればOK
#     - reshapeだと、numpyの配列となるので、その点は異なる。

# %%
n = 65

img_name = landmarks_frame.iloc[n, 0]
landmarks = landmarks_frame.iloc[n, 1:].as_matrix()
# reshapeの次元で-1を指定することも可能
# この場合、入力配列の要素数と残りのshapeの次元から、
# -1に指定した次元の要素数が自動で判別される
# reshape(-1)とすると、flatten()と同じになる。

# (x,y)を列として各特徴点を行にするように形状を変換
landmarks = landmarks.astype('float').reshape(-1, 2)

print('Image name: {}'.format(img_name))
print('Landmarks shape: {}'.format(landmarks.shape))
print('First 4 Landmarks:\n {}'.format(landmarks[:4]))
# Out:
# Image name: person-7.jpg
# Landmarks shape: (68, 2)
# First 4 Landmarks:
#  [[32. 65.]
#  [33. 76.]
#  [34. 86.]
#  [34. 97.]]

# %% [markdown]
# PyTorchを使わず、この特徴点を描画しようとすると、
# おそらく以下のようにヘルパー関数を作成して、描画していくことになる。

# %%
def show_landmarks(image, landmarks):
    """Show image with landmarks"""
    plt.imshow(image)
    plt.scatter(landmarks[:, 0], landmarks[:, 1], s=10, marker='.', c='r')
    plt.pause(0.001)  # pause a bit so that plots are updated

plt.figure()
show_landmarks(io.imread(os.path.join('data/faces/', img_name)),
               landmarks)
plt.show()

# %% [markdown]
# ## PyTorchのDatadetを使用する
#
# ### Datasetクラス
#
# Datasetは抽象クラスでこれを継承して自由にDataset関連のクラスを自作できる。
#
# その際、以下のメソッドはオーバーライドする必要がある。
#
# - `__len__`
#     - 要は、len(dataset)のときの処理
#     - datasetの長さを返す処理を記述する
# - `__getitem__`
#     - indexingをサポートするための処理
#     - つまり、`i`番目の要素にたいして、`dataset[i]`でアクセスできるようにする

# %%
class FaceLandmarksDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir,
                                self.landmarks_frame.iloc[idx, 0])
        image = io.imread(img_name)
        landmarks = self.landmarks_frame.iloc[idx, 1:]
        landmarks = np.array([landmarks])
        landmarks = landmarks.astype('float').reshape(-1, 2)
        sample = {'image': image, 'landmarks': landmarks}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
face_dataset = FaceLandmarksDataset(csv_file='data/faces/face_landmarks.csv',
                                    root_dir='data/faces/')

fig = plt.figure()

for i in range(len(face_dataset)):
    sample = face_dataset[i]

    print(i, sample['image'].shape, sample['landmarks'].shape)

    ax = plt.subplot(1, 4, i + 1)
    plt.tight_layout()
    ax.set_title('Sample #{}'.format(i))
    ax.axis('off')
    show_landmarks(**sample)

    if i == 3:
        plt.show()
        break
# Out:
# 0 (324, 215, 3) (68, 2)
# 1 (500, 333, 3) (68, 2)
# 2 (250, 258, 3) (68, 2)
# 3 (434, 290, 3) (68, 2)

# %% [markdown]
# ### Transform
#
# 以下のような変換処理を実装する
#
# - `Rescale`: 画像サイズの変換
# - `RandomCrop`: 画像からランダムに切り取り
# - `ToTensor`: numpy-arrayからtorch.Tensorに変換
#
# 単純な関数ではなく、callableクラスとして実装する。
#
# その理由としては、変換処理をコールする度に、入力データ以外のパラメータを渡す必要がないので、
# 記述がシンプルになること。
#
# つまり、コンストラクタでパラメータ(例えば切り取る画像のサイズ)を渡して、
# callableなオブジェクトを作成しておく。
# 変換処理の際には、それに入力データを入れてcallするだけでOKとなる。
#
# ```python
# trans = Transform(params)
# trans(input_data)
# ```

# %%
class Rescale(object):
    """Rescale the image in a sample to a given size.

    Args:
        output_size (tuple or int): Desired output size. If tuple, output is
            matched to output_size. If int, smaller of image edges is matched
            to output_size keeping aspect ratio the same.
    """

    def __init__(self, output_size):
        """
        Parameters
        ----------
        output_size  : int or tuple
            リスケール後の画像サイズ
            ※ intで指定した場合は正方画像となる。
        """
        assert isinstance(output_size, (int, tuple))
        self.output_size = output_size

    def __call__(self, sample):
        image, landmarks = sample['image'], sample['landmarks']

        h, w = image.shape[:2]
        if isinstance(self.output_size, int):
            if h > w:
                new_h, new_w = self.output_size * h / w, self.output_size
            else:
                new_h, new_w = self.output_size, self.output_size * w / h
        else:
            new_h, new_w = self.output_size

        new_h, new_w = int(new_h), int(new_w)

        img = transform.resize(image, (new_h, new_w))

        # h and w are swapped for landmarks because for images,
        # x and y axes are axis 1 and 0 respectively
        landmarks = landmarks * [new_w / w, new_h / h]

        return {'image': img, 'landmarks': landmarks}


class RandomCrop(object):
    """Crop randomly the image in a sample.

    Args:
        output_size (tuple or int): Desired output size. If int, square crop
            is made.
    """

    def __init__(self, output_size):
        assert isinstance(output_size, (int, tuple))
        if isinstance(output_size, int):
            self.output_size = (output_size, output_size)
        else:
            assert len(output_size) == 2
            self.output_size = output_size

    def __call__(self, sample):
        image, landmarks = sample['image'], sample['landmarks']

        h, w = image.shape[:2]
        new_h, new_w = self.output_size

        top = np.random.randint(0, h - new_h)
        left = np.random.randint(0, w - new_w)

        image = image[top: top + new_h,
                      left: left + new_w]

        landmarks = landmarks - [left, top]

        return {'image': image, 'landmarks': landmarks}


class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, landmarks = sample['image'], sample['landmarks']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        return {'image': torch.from_numpy(image),
                'landmarks': torch.from_numpy(landmarks)}

# %% [markdown]
# `tourchvision.transforms.Compose`に実行したい処理をリスト形式で渡すと、
# その処理を順次実行するオブジェクトを作成される。
#
# ```python
# composed = torchvision.transforms.Composed([Rescale(256), RandomCrop(224)])
#
# # sampleに対してRescaleとRandomCropが実行される
# composed(sample)
# ```

# %% [markdown]
# 変換処理を上記では手で実装したが、
# `torchvision.transdorms`では、一通りの機能が機能を持ったクラスが
# すでに実装されているので、それを流用したほうがよい。
#
# 詳細については、
# [公式](https://pytorch.org/docs/stable/torchvision/transforms.html)
# のドキュメントを参照のこと。

# %%
scale = Rescale(256)
crop = RandomCrop(128)
composed = torchvision.transforms.Compose([Rescale(256),
                                           RandomCrop(224)])

# Apply each of the above transforms on sample.
fig = plt.figure()
sample = face_dataset[65]
for i, tsfrm in enumerate([scale, crop, composed]):
    transformed_sample = tsfrm(sample)

    ax = plt.subplot(1, 3, i + 1)
    plt.tight_layout()
    ax.set_title(type(tsfrm).__name__)
    show_landmarks(**transformed_sample)

plt.show()

# %% [markdown]
# ### Iterationg through the data
#
# 単純にfor文を用いてiterateすることも可能だが(直下のセルのように)、
# もっと良い方法がある。
#
# というのも、for文を使ってiterate処理してしまうと、以下の機能が使えなくなってしまう。
#
# - データのバッチ処理
# - データのシャッフル
# - 並列化したデータロード
#
# ---
#
# `torch.utils.data.DataLoader`はこれらすべてのの機能を提供できるitarator。
#
# `Dataset`を継承したクラスをこいつに渡せば、うまいことやってくれる。

# %%
# このセルの処理はあまり推奨しない(for文を使わないほうがいろいろ楽)
transformed_dataset = FaceLandmarksDataset(csv_file='data/faces/face_landmarks.csv',
                                           root_dir='data/faces/',
                                           transform=transforms.Compose([
                                               Rescale(256),
                                               RandomCrop(224),
                                               ToTensor()
                                           ]))

for i in range(len(transformed_dataset)):
    sample = transformed_dataset[i]

    print(i, sample['image'].size(), sample['landmarks'].size())

    if i == 3:
        break
# Out:
# 0 torch.Size([3, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([3, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([3, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([3, 224, 224]) torch.Size([68, 2])

# %%
# Datasetを継承したオブジェクト(FaceLandmarksDatasetクラス)を渡す。
dataloader = DataLoader(transformed_dataset, batch_size=4,
                        shuffle=True, num_workers=0)


# Helper function to show a batch
def show_landmarks_batch(sample_batched):
    """Show image with landmarks for a batch of samples."""
    images_batch, landmarks_batch = \
            sample_batched['image'], sample_batched['landmarks']
    batch_size = len(images_batch)
    im_size = images_batch.size(2)
    grid_border_size = 2

    grid = utils.make_grid(images_batch)
    plt.imshow(grid.numpy().transpose((1, 2, 0)))

    for i in range(batch_size):
        plt.scatter(landmarks_batch[i, :, 0].numpy() + i * im_size + (i + 1) * grid_border_size,
                    landmarks_batch[i, :, 1].numpy() + grid_border_size,
                    s=10, marker='.', c='r')

        plt.title('Batch from dataloader')

# DataLoaderのオブジェクトはiterativeであり、
# コンストラクタで渡したバッチサイズに分けたデータセットを
# 順次返していく。
for i_batch, sample_batched in enumerate(dataloader):
    print(i_batch, sample_batched['image'].size(),
          sample_batched['landmarks'].size())

    # observe 4th batch and stop.
    if i_batch == 3:
        plt.figure()
        show_landmarks_batch(sample_batched)
        plt.axis('off')
        plt.ioff()
        plt.show()
        break
# Out:
# 0 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# 1 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# 2 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
# 3 torch.Size([4, 3, 224, 224]) torch.Size([4, 68, 2])
